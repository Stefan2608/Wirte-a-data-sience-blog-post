# %% [markdown]
# # Coding in Germany
#
# <img src='https://pixnio.com/free-images/2017/03/24/2017-03-24-10-10-55-725x483.jpg'></img>

# %% [markdown]
# ## Introduction
#
# Digitalization has been talking about for years and how it is changing companies. But in the meantime, this no longer only means Apple or Google, but also the German middle class. Today, it is no longer just large software or hardware companies that need developers and programmers for new technologies, but almost every company. Even many nurseries, for example, have a website, many companies need an app or an online shop to stay competitive in the market.
#
# The social network LinkedIn commissioned a study in 2015, for which around 300 managing directors and HR managers in Germany were interviewed. She showed that "understanding of programming" is one of the most important skills of employees, which will continue to gain importance in the future.
#
# That's why I decided with the help of the Stockoverflow 2019 Annual developer survey to get to the bottom of what the 2019 developer scene looks like. Almost 90,000 developers participated and covering everything from developers’ favorite technologies to their job preferences.

# %%
#Import librarys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df19 = pd.read_csv('./survey_results_public.csv')
sm = pd.read_csv('./survey_results_schema.csv')

# View data
df19.head()
# Out:
# /opt/anaconda/envs/python36/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %%
#filter for germany
rel_land = ['Germany']

df_germany = df19[df19['Country'].isin(rel_land)]

df_germany
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 13             14  I am a developer by profession      Yes
# 35             36  I am a developer by profession      Yes
# 43             44  I am a developer by profession      Yes
# 65             66  I am a developer by profession      Yes
# 84             85  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88740       64465                             NaN      Yes
# 88779       71055                             NaN      Yes
# 88804       75974                             NaN      Yes
# 88829       80319                             NaN      Yes
# 88850       83786                             NaN       No
#
#                                              OpenSourcer  \
# 13                               Less than once per year
# 35     Less than once a month but more than once per ...
# 43                            Once a month or more often
# 65                            Once a month or more often
# 84                                                 Never
# ...                                                  ...
# 88740                            Less than once per year
# 88779                                              Never
# 88804                         Once a month or more often
# 88829                                              Never
# 88850                         Once a month or more often
#
#                                               OpenSource  \
# 13     The quality of OSS and closed source software ...
# 35     The quality of OSS and closed source software ...
# 43     The quality of OSS and closed source software ...
# 65     OSS is, on average, of HIGHER quality than pro...
# 84     OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88740  The quality of OSS and closed source software ...
# 88779  OSS is, on average, of LOWER quality than prop...
# 88804  OSS is, on average, of HIGHER quality than pro...
# 88829  OSS is, on average, of HIGHER quality than pro...
# 88850  The quality of OSS and closed source software ...
#
#                                               Employment  Country  \
# 13                                    Employed full-time  Germany
# 35                                    Employed full-time  Germany
# 43                                    Employed full-time  Germany
# 65                                    Employed full-time  Germany
# 84     Independent contractor, freelancer, or self-em...  Germany
# ...                                                  ...      ...
# 88740                                                NaN  Germany
# 88779             Not employed, and not looking for work  Germany
# 88804                                 Employed full-time  Germany
# 88829  Independent contractor, freelancer, or self-em...  Germany
# 88850                                 Employed full-time  Germany
#
#               Student                                            EdLevel  \
# 13                 No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 35     Yes, full-time  Secondary school (e.g. American high school, G...
# 43                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65                 No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 84                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...               ...                                                ...
# 88740              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88779              No                                                NaN
# 88804              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88829              No  Secondary school (e.g. American high school, G...
# 88850              No          Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                                           UndergradMajor  ...  \
# 13     Computer science, computer engineering, or sof...  ...
# 35                                                   NaN  ...
# 43     Information systems, information technology, o...  ...
# 65     Computer science, computer engineering, or sof...  ...
# 84     Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 88740  A business discipline (ex. accounting, finance...  ...
# 88779  A social science (ex. anthropology, psychology...  ...
# 88804  Another engineering discipline (ex. civil, ele...  ...
# 88829                                                NaN  ...
# 88850  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 13      Just as welcome now as I felt last year
# 35     Somewhat less welcome now than last year
# 43      Just as welcome now as I felt last year
# 65      Just as welcome now as I felt last year
# 84     Somewhat less welcome now than last year
# ...                                         ...
# 88740   Just as welcome now as I felt last year
# 88779     A lot more welcome now than last year
# 88804   Just as welcome now as I felt last year
# 88829  Somewhat more welcome now than last year
# 88850   Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 13     Tech articles written by other developers;Cour...  31.0    Man    No
# 35                                                   NaN  21.0    Man    No
# 43     Tech articles written by other developers;Indu...  43.0    Man    No
# 65                                                   NaN   NaN    NaN   NaN
# 84     Tech articles written by other developers;Tech...  31.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88740                                                NaN   NaN    Man    No
# 88779  Industry news about technologies you're intere...   2.0    Man   NaN
# 88804  Industry news about technologies you're intere...   NaN    Man    No
# 88829  Tech articles written by other developers;Tech...  18.0    Man    No
# 88850  Tech articles written by other developers;Indu...  57.0    Man    No
#
#                      Sexuality                     Ethnicity Dependents  \
# 13     Straight / Heterosexual  White or of European descent         No
# 35     Straight / Heterosexual  White or of European descent         No
# 43     Straight / Heterosexual  White or of European descent        Yes
# 65                         NaN                           NaN        Yes
# 84     Straight / Heterosexual  White or of European descent        NaN
# ...                        ...                           ...        ...
# 88740  Straight / Heterosexual  White or of European descent         No
# 88779                      NaN                           NaN        NaN
# 88804                      NaN                Middle Eastern        Yes
# 88829  Straight / Heterosexual                           NaN         No
# 88850                      NaN  White or of European descent        Yes
#
#                 SurveyLength                  SurveyEase
# 13                 Too short                        Easy
# 35                  Too long  Neither easy nor difficult
# 43     Appropriate in length                        Easy
# 65                  Too long  Neither easy nor difficult
# 84     Appropriate in length                        Easy
# ...                      ...                         ...
# 88740  Appropriate in length  Neither easy nor difficult
# 88779               Too long                   Difficult
# 88804  Appropriate in length                        Easy
# 88829  Appropriate in length                        Easy
# 88850               Too long  Neither easy nor difficult
#
# [5866 rows x 85 columns]

# %% [markdown]
# ## Part I: The Basics
# Developers age and when the begin with coding?

# %%
Age = df_germany.Age.value_counts().sort_values(ascending = False)
df_germany.Age.plot.box()
axis = plt.gca()
axis.set_ylim(0, 60)
# Out:
# (0, 60)

# %% [markdown]
# The average age structure of the developers is just under 30 years.
# The range from mid-20 to mid-30 corresponds to a very good mix.

# %%
Age1Code = df_germany.Age1stCode.value_counts().sort_values(ascending = False)
Age1Code.plot(kind='barh', figsize=(10,8))

# %% [markdown]
# It is also interesting to ask at what age these people first came into contact with programming.
# After the analysis you can see in the diagram above that most of them started programming when they were teenagers.
# A good transition to my second key question, which deals with educational background.
#
# Has the classic IT education path been taken here, as might suspect?

# %% [markdown]
# ## Part II: Background
# Whats the educational background of the developers?

# %%
#Analysing major data
major = df_germany.UndergradMajor.value_counts().sort_values(ascending = False)
major

print(major.sum())
# Out:
# 4465

# %%
#Analysing major data
ed_level = df_germany.EdLevel.value_counts().sort_values(ascending = False)

ed_level
print(ed_level.sum())
# Out:
# 5674

# %% [markdown]
# From the missing data in the degrees, I conclude that the majority did not aim for a higher education
# or it did not meet the query criteria.
#
# For this reason I decided to replace the missing data with the entry "Empty" and to compare it with the education level.

# %%
#Fillup the Nan values
df_germany['UndergradMajor'].fillna('Empty', inplace=True)
df_germany['EdLevel'].fillna('Empty', inplace=True)

print(major.sum())
print(ed_level.sum())
# Out:
# 4465
# 5674
# /opt/anaconda/envs/python36/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
#major plot
(major/df_germany.shape[0]*100).plot(kind="barh", color = 'purple');
plt.title("Major");

# %%
#education plot

compare = df_germany.groupby('UndergradMajor').EdLevel.value_counts().sort_values(ascending = False)

temp = compare.sort_values(ascending=False)


compare[:10].plot.barh();

# %% [markdown]
# As you can see, many developers continue to educate themselves who have no higher education.
#
# From this it can be deduced that programming is also an option for career changers.
#
# One might consider introducing programming to the education system as a major at high school.

# %% [markdown]
# ## Part III: Organization
# Do small companies also have developers among their employees?

# %%
#Analizing organizaion structure
org = df_germany.groupby('OrgSize').size()#.reset_index(name='counts')

org
# Out:
# OrgSize
# 1,000 to 4,999 employees                               503
# 10 to 19 employees                                     446
# 10,000 or more employees                               588
# 100 to 499 employees                                   962
# 2-9 employees                                          432
# 20 to 99 employees                                    1126
# 5,000 to 9,999 employees                               186
# 500 to 999 employees                                   336
# Just me - I am a freelancer, sole proprietor, etc.     271
# dtype: int64

# %%
#org plot
org.plot(kind='pie', subplots=True, figsize=(8,8))

plt.title("Org Structure")
plt.ylabel("Count")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Based on the data, we see that the majority of developers are active in medium-sized companies.
#
# Large companies are less represented, which suggests that external contracts are being placed here.

# %% [markdown]
# ## Conclution
#
# At the end of my rather limited analysis it can be said, that the development scene in Germany is quite well positioned.
#
# The age structure corresponds in a good area and covers the beginner as well as the experienced career area.
#
# The educational offers are very beginner-friendly, which can be seen  in the educational statistics, not only hardcore IT graduates are present, but also career changers with a lower educational background.
#
# The corporate structure shows that a large number of developers are located in the middle class, but there are also freelancers who are sure to be happy to move the nursery next door into the digital age.

# %% [markdown]
# ### How the situtaion in your country? Feel free to check it out and share your results!
